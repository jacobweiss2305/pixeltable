# %% [markdown]
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/pixeltable/pixeltable/blob/release/docs/notebooks/integrations/working-with-llama.ipynb)&nbsp;&nbsp;
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pixeltable/pixeltable/blob/release/docs/notebooks/integrations/working-with-llama.ipynb)&nbsp;&nbsp;
# <a href="https://raw.githubusercontent.com/pixeltable/pixeltable/release/docs/notebooks/integrations/working-with-llama.ipynb" download><img src="https://img.shields.io/badge/%E2%AC%87-Download%20Notebook-blue" alt="Download Notebook"></a>
#
# # Working with Llama in Pixeltable
#
# Pixeltable's Llama integration enables you to access Llama's LLM and other models via the Llama AI API.
#
# ### Prerequisites
#
# - A Llama AI account with an API key (https://llama.developer.meta.com/)
#
# ### Important Notes
#
# - Llama usage may incur costs based on your Llama AI plan.
# - Be mindful of sensitive data and consider security measures when integrating with external services.
#
# First you'll need to install required libraries and enter a Llama AI API key.

# %%
# %pip install -qU pixeltable openai
# Out:
# Running cells with 'Python 3.13.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import os
import getpass

if 'LLAMA_API_KEY' not in os.environ:
    os.environ['LLAMA_API_KEY'] = getpass.getpass('Llama AI API Key:')

# %% [markdown]
# Now let's create a Pixeltable directory to hold the tables for our demo.

# %%
import pixeltable as pxt

# Remove the `llama_demo` directory and its contents, if it exists
pxt.drop_dir('llama_demo', force=True)
pxt.create_dir('llama_demo')
# Out:
# Timeout starting server.
# Showing contents of postgres server log (C:\Users\jawei\.pixeltable\pgdata\log) below:
# 2025-04-30 16:42:59.531 MDT [25176] LOG:  starting PostgreSQL 16.8 on x86_64-pc-mingw64, compiled by gcc.exe (x86_64-posix-seh-rev2, Built by MinGW-W64 project) 12.2.0, 64-bit
# 2025-04-30 16:42:59.531 MDT [25176] LOG:  listening on IPv4 address "127.0.0.1", port 51604
# 2025-04-30 16:42:59.551 MDT [27480] LOG:  database system was shut down at 2025-04-30 16:42:54 MDT
# 2025-04-30 16:42:59.563 MDT [25176] LOG:  database system is ready to accept connections
# 2025-04-30 16:47:59.554 MDT [15000] LOG:  checkpoint starting: time
# 2025-04-30 16:49:53.575 MDT [15000] LOG:  checkpoint complete: wrote 1050 buffers (6.4%); 0 WAL file(s) added, 0 removed, 0 recycled; write=113.885 s, sync=0.128 s, total=114.022 s; sync files=357, longest=0.003 s, average=0.001 s; distance=4930 kB, estimate=4930 kB; lsn=0/19523F0, redo lsn=0/19523B8
# 2025-04-30 16:58:04.204 MDT [20228] LOG:  could not receive data from client: An existing connection was forcibly closed by the remote host.
#
# 2025-04-30 16:58:04.204 MDT [12948] LOG:  could not receive data from client: An existing connection was forcibly closed by the remote host.
#
# 2025-04-30 16:58:19.998 MDT [25176] LOG:  server process (PID 6496) was terminated by exception 0xC0000142
# 2025-04-30 16:58:19.998 MDT [25176] HINT:  See C include file "ntstatus.h" for a description of the hexadecimal value.
# 2025-04-30 16:58:19.998 MDT [25176] LOG:  terminating any other active server processes
# 2025-04-30 16:58:20.003 MDT [25176] LOG:  all server processes terminated; reinitializing
# 2025-04-30 16:58:20.036 MDT [25176] LOG:  startup process (PID 25100) was terminated by exception 0xC0000142
# 2025-04-30 16:58:20.036 MDT [25176] HINT:  See C include file "ntstatus.h" for a description of the hexadecimal value.
# 2025-04-30 16:58:20.036 MDT [25176] LOG:  aborting startup due to startup process failure
# 2025-04-30 16:58:20.042 MDT [25176] LOG:  database system is shut down
# 2025-05-02 14:47:13.690 MDT [28744] LOG:  starting PostgreSQL 16.8 on x86_64-pc-mingw64, compiled by gcc.exe (x86_64-posix-seh-rev2, Built by MinGW-W64 project) 12.2.0, 64-bit
# 2025-05-02 14:47:13.691 MDT [28744] LOG:  listening on IPv4 address "127.0.0.1", port 53505
# 2025-05-02 14:47:13.730 MDT [6136] LOG:  database system was interrupted; last known up at 2025-04-30 16:49:53 MDT
# 2025-05-02 14:47:19.860 MDT [6136] LOG:  could not open file "./log": sharing violation
# 2025-05-02 14:47:19.860 MDT [6136] DETAIL:  Continuing to retry for 30 seconds.
# 2025-05-02 14:47:19.860 MDT [6136] HINT:  You might have antivirus, backup, or similar software interfering with the database system.
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pixeltable as pxt
#       3 # Remove the `llama_demo` directory and its contents, if it exists
# ----> 4 pxt.drop_dir('llama_demo', force=True)
#       5 pxt.create_dir('llama_demo')
#
# File ~\my-pixeltable\pixeltable\pixeltable\globals.py:603, in drop_dir(path, force, if_not_exists)
#     601 path_obj = catalog.Path(path)  # validate format
#     602 if_not_exists_ = catalog.IfNotExistsParam.validated(if_not_exists, 'if_not_exists')
# --> 603 Catalog.get().drop_dir(path_obj, if_not_exists=if_not_exists_, force=force)
#
# File ~\my-pixeltable\pixeltable\pixeltable\catalog\catalog.py:106, in Catalog.get(cls)
#     103 @classmethod
#     104 def get(cls) -> Catalog:
#     105     if cls._instance is None:
# --> 106         cls._instance = cls()
#     107     return cls._instance
#
# File ~\my-pixeltable\pixeltable\pixeltable\catalog\catalog.py:117, in Catalog.__init__(self)
#     115 self._tbl_versions = {}
#     116 self._tbls = {}  # don't use a defaultdict here, it doesn't cooperate with the debugger
# --> 117 self._init_store()
#
# File ~\my-pixeltable\pixeltable\pixeltable\catalog\catalog.py:1027, in Catalog._init_store(self)
#    1025 def _init_store(self) -> None:
#    1026     """One-time initialization of the stored catalog. Idempotent."""
# -> 1027     self.create_user(None)
#    1028     _logger.info('Initialized catalog.')
#
# File ~\my-pixeltable\pixeltable\pixeltable\catalog\catalog.py:1034, in Catalog.create_user(self, user)
#    1030 def create_user(self, user: Optional[str]) -> None:
#    1031     """
#    1032     Creates a catalog record (root directory) for the specified user, if one does not already exist.
#    1033     """
# -> 1034     with Env.get().begin_xact():
#    1035         session = Env.get().session
#    1036         # See if there are any directories in the catalog matching the specified user.
#
# File ~\my-pixeltable\pixeltable\pixeltable\env.py:92, in Env.get(cls)
#      89 @classmethod
#      90 def get(cls) -> Env:
#      91     if cls._instance is None:
# ---> 92         cls._init_env()
#      93     return cls._instance
#
# File ~\my-pixeltable\pixeltable\pixeltable\env.py:100, in Env._init_env(cls, reinit_db)
#      98 cls.__initializing = True
#      99 env = Env()
# --> 100 env._set_up(reinit_db=reinit_db)
#     101 env._upgrade_metadata()
#     102 cls._instance = env
#
# File ~\my-pixeltable\pixeltable\pixeltable\env.py:376, in Env._set_up(self, echo, reinit_db)
#     373 self.clear_tmp_dir()
#     375 # configure pixeltable database
# --> 376 self._init_db(config)
#     378 if reinit_db and not self.is_local:
#     379     raise excs.Error(
#     380         'Reinitializing pixeltable database is not supported when running in non-local environment'
#     381     )
#
# File ~\my-pixeltable\pixeltable\pixeltable\env.py:450, in Env._init_db(self, config)
#     445 # cleanup_mode=None will leave the postgres process running after Python exits
#     446 # cleanup_mode='stop' will terminate the postgres process when Python exits
#     447 # On Windows, we need cleanup_mode='stop' because child processes are killed automatically when the parent
#     448 # process (such as Terminal or VSCode) exits, potentially leaving it in an unusable state.
#     449 cleanup_mode = 'stop' if platform.system() == 'Windows' else None
# --> 450 self._db_server = pixeltable_pgserver.get_server(self._pgdata_dir, cleanup_mode=cleanup_mode)
#     451 self._db_url = self._db_server.get_uri(database=self._db_name, driver='psycopg')
#     452 self._dbms = PostgresqlDbms(sql.make_url(self._db_url))
#
# File c:\Users\jawei\my-pixeltable\pixeltable\docs\notebooks\integrations\.venv\Lib\site-packages\pixeltable_pgserver\postgres_server.py:306, in get_server(pgdata, cleanup_mode)
#     303 if pgdata in PostgresServer._instances:
#     304     return PostgresServer._instances[pgdata]
# --> 306 return PostgresServer(pgdata, cleanup_mode=cleanup_mode)
#
# File c:\Users\jawei\my-pixeltable\pixeltable\docs\notebooks\integrations\.venv\Lib\site-packages\pixeltable_pgserver\postgres_server.py:69, in PostgresServer.__init__(self, pgdata, cleanup_mode)
#      67 self._instances[self.pgdata] = self
#      68 self.ensure_pgdata_inited()
# ---> 69 self.ensure_postgres_running()
#      70 self.global_process_id_list.get_and_add(os.getpid())
#
# File c:\Users\jawei\my-pixeltable\pixeltable\docs\notebooks\integrations\.venv\Lib\site-packages\pixeltable_pgserver\postgres_server.py:199, in PostgresServer.ensure_postgres_running(self)
#     195 except subprocess.TimeoutExpired as err:
#     196     _logger.error(
#     197         f'Timeout starting server.\nShowing contents of postgres server log ({self.log.absolute()}) below:\n{self.log.read_text()}'
#     198     )
# --> 199     raise err
#     201 while True:
#     202     # in Windows, when there is a postmaster.pid,  init_ctl seems to return
#     203     # but the file is not immediately updated, here we wait until the file shows
#     204     # a new running server. see test_stale_postmaster
#     205     _logger.info(f'waiting for postmaster info to show a running process')
#
# File c:\Users\jawei\my-pixeltable\pixeltable\docs\notebooks\integrations\.venv\Lib\site-packages\pixeltable_pgserver\postgres_server.py:189, in PostgresServer.ensure_postgres_running(self)
#     187 try:
#     188     _logger.info(f'running pg_ctl... {pg_ctl_args=}')
# --> 189     pg_ctl(pg_ctl_args, pgdata=self.pgdata, user=self.system_user, timeout=10)
#     190 except subprocess.CalledProcessError as err:
#     191     _logger.error(
#     192         f'Failed to start server.\nShowing contents of postgres server log ({self.log.absolute()}) below:\n{self.log.read_text()}'
#     193     )
#
# File c:\Users\jawei\my-pixeltable\pixeltable\docs\notebooks\integrations\.venv\Lib\site-packages\pixeltable_pgserver\_commands.py:41, in create_command_function.<locals>.command(args, pgdata, **kwargs)
#      37 _logger.info('Running commandline:\n%s\nwith kwargs: `%s`', full_command_line, kwargs)
#      38 # NB: capture_output=True, as well as using stdout=subprocess.PIPE and stderr=subprocess.PIPE
#      39 # can cause this call to hang, even with a time-out depending on the command, (pg_ctl)
#      40 # so we use two temporary files instead
# ---> 41 result = subprocess.run(
#      42     full_command_line, check=True, stdout=stdout, stderr=stderr, text=True, **kwargs
#      43 )
#      44 stdout.seek(0)
#      45 stderr.seek(0)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\subprocess.py:1238, in Popen.communicate(self, input, timeout)
#    1235     finally:
#    1236         self._communication_started = True
# -> 1238     sts = self.wait(timeout=self._remaining_time(endtime))
#    1240 return (stdout, stderr)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\subprocess.py:1274, in Popen.wait(self, timeout)
#    1272     endtime = _time() + timeout
#    1273 try:
# -> 1274     return self._wait(timeout=timeout)
#    1275 except KeyboardInterrupt:
#    1276     # https://bugs.python.org/issue25942
#    1277     # The first keyboard interrupt waits briefly for the child to
#    1278     # exit under the common assumption that it also received the ^C
#    1279     # generated SIGINT and will exit rapidly.
#    1280     if timeout is not None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\subprocess.py:1603, in Popen._wait(self, timeout)
#    1600     result = _winapi.WaitForSingleObject(self._handle,
#    1601                                          timeout_millis)
#    1602     if result == _winapi.WAIT_TIMEOUT:
# -> 1603         raise TimeoutExpired(self.args, timeout)
#    1604     self.returncode = _winapi.GetExitCodeProcess(self._handle)
#    1605 return self.returncode
#
# TimeoutExpired: Command '['c:\\Users\\jawei\\my-pixeltable\\pixeltable\\docs\\notebooks\\integrations\\.venv\\Lib\\site-packages\\pixeltable_pgserver\\pginstall\\bin\\pg_ctl.exe', '-D', 'C:\\Users\\jawei\\.pixeltable\\pgdata', '-w', '-o', '-h "127.0.0.1"', '-o', '-p 53505', '-l', 'C:\\Users\\jawei\\.pixeltable\\pgdata\\log', 'start']' timed out after 9.99999390001176 seconds

# %% [markdown]
# ## Messages
#
# Create a Table: In Pixeltable, create a table with columns to represent your input data and the columns where you want to store the results from Llama.

# %%
from pixeltable.functions.llama import chat_completions

# Create a table in Pixeltable and pick a model hosted on Llama with some parameters

t = pxt.create_table('llama_demo.chat', {'input': pxt.String})

messages = [{'role': 'user', 'content': t.input}]
t.add_computed_column(output=chat_completions(
    messages=messages,
    model='Llama-4-Scout-17B-16E-Instruct-FP8',
    # These parameters are optional and can be used to tune model behavior:
    max_tokens=300,
    top_p=0.9,
    temperature=0.7
))

# %%
# Parse the response into a new column
t.add_computed_column(response=t.output.choices[0].message.content)

# %%
# Start a conversation
t.insert(input="What three species of fish have the highest mercury content?")
t.select(t.input, t.response).show()

# %% [markdown]
# ### Learn More
#
# To learn more about advanced techniques like RAG operations in Pixeltable, check out the [RAG Operations in Pixeltable](https://pixeltable.readme.io/docs/rag-operations-in-pixeltable) tutorial.
#
# If you have any questions, don't hesitate to reach out.
